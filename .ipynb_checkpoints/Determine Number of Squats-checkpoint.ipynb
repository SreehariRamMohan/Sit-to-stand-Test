# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json

# %%
JSON_DATA_PATH = "/Users/sreeharirammohan/Desktop/SCP_FOLDER/video_2/json"

# %%
all_json_files = os.listdir(JSON_DATA_PATH)

# %%
#order the json files from the first frame to the last. 
all_json_files.sort()

# %%
#first item in the list is the DS STORE, remove
del all_json_files[0]

# %%
all_json_files
# Out:
# ['video_000000002458_keypoints.json',
#  'video_000000002459_keypoints.json',
#  'video_000000002460_keypoints.json',
#  'video_000000002461_keypoints.json',
#  'video_000000002462_keypoints.json',
#  'video_000000002463_keypoints.json',
#  'video_000000002464_keypoints.json',
#  'video_000000002465_keypoints.json',
#  'video_000000002466_keypoints.json',
#  'video_000000002467_keypoints.json',
#  'video_000000002468_keypoints.json',
#  'video_000000002469_keypoints.json',
#  'video_000000002470_keypoints.json',
#  'video_000000002471_keypoints.json',
#  'video_000000002472_keypoints.json',
#  'video_000000002473_keypoints.json',
#  'video_000000002474_keypoints.json',
#  'video_000000002475_keypoints.json',
#  'video_000000002476_keypoints.json',
#  'video_000000002477_keypoints.json',
#  'video_000000002478_keypoints.json',
#  'video_000000002479_keypoints.json',
#  'video_000000002480_keypoints.json',
#  'video_000000002481_keypoints.json',
#  'video_000000002482_keypoints.json',
#  'video_000000002483_keypoints.json',
#  'video_000000002484_keypoints.json',
#  'video_000000002485_keypoints.json',
#  'video_000000002486_keypoints.json',
#  'video_000000002487_keypoints.json',
#  'video_000000002488_keypoints.json',
#  'video_000000002489_keypoints.json',
#  'video_000000002490_keypoints.json',
#  'video_000000002491_keypoints.json',
#  'video_000000002492_keypoints.json',
#  'video_000000002493_keypoints.json',
#  'video_000000002494_keypoints.json',
#  'video_000000002495_keypoints.json',
#  'video_000000002496_keypoints.json',
#  'video_000000002497_keypoints.json',
#  'video_000000002498_keypoints.json',
#  'video_000000002499_keypoints.json',
#  'video_000000002500_keypoints.json',
#  'video_000000002501_keypoints.json',
#  'video_000000002502_keypoints.json',
#  'video_000000002503_keypoints.json',
#  'video_000000002504_keypoints.json',
#  'video_000000002505_keypoints.json',
#  'video_000000002506_keypoints.json',
#  'video_000000002507_keypoints.json',
#  'video_000000002508_keypoints.json',
#  'video_000000002509_keypoints.json',
#  'video_000000002510_keypoints.json',
#  'video_000000002511_keypoints.json',
#  'video_000000002512_keypoints.json',
#  'video_000000002513_keypoints.json',
#  'video_000000002514_keypoints.json',
#  'video_000000002515_keypoints.json',
#  'video_000000002516_keypoints.json',
#  'video_000000002517_keypoints.json',
#  'video_000000002518_keypoints.json',
#  'video_000000002519_keypoints.json',
#  'video_000000002520_keypoints.json',
#  'video_000000002521_keypoints.json',
#  'video_000000002522_keypoints.json',
#  'video_000000002523_keypoints.json',
#  'video_000000002524_keypoints.json',
#  'video_000000002525_keypoints.json',
#  'video_000000002526_keypoints.json',
#  'video_000000002527_keypoints.json',
#  'video_000000002528_keypoints.json',
#  'video_000000002529_keypoints.json',
#  'video_000000002530_keypoints.json',
#  'video_000000002531_keypoints.json',
#  'video_000000002532_keypoints.json',
#  'video_000000002533_keypoints.json',
#  'video_000000002534_keypoints.json',
#  'video_000000002535_keypoints.json',
#  'video_000000002536_keypoints.json',
#  'video_000000002537_keypoints.json',
#  'video_000000002538_keypoints.json',
#  'video_000000002539_keypoints.json',
#  'video_000000002540_keypoints.json',
#  'video_000000002541_keypoints.json',
#  'video_000000002542_keypoints.json',
#  'video_000000002543_keypoints.json',
#  'video_000000002544_keypoints.json',
#  'video_000000002545_keypoints.json',
#  'video_000000002546_keypoints.json',
#  'video_000000002547_keypoints.json',
#  'video_000000002548_keypoints.json',
#  'video_000000002549_keypoints.json',
#  'video_000000002550_keypoints.json',
#  'video_000000002551_keypoints.json',
#  'video_000000002552_keypoints.json',
#  'video_000000002553_keypoints.json',
#  'video_000000002554_keypoints.json',
#  'video_000000002555_keypoints.json',
#  'video_000000002556_keypoints.json',
#  'video_000000002557_keypoints.json',
#  'video_000000002558_keypoints.json',
#  'video_000000002559_keypoints.json',
#  'video_000000002560_keypoints.json',
#  'video_000000002561_keypoints.json',
#  'video_000000002562_keypoints.json',
#  'video_000000002563_keypoints.json',
#  'video_000000002564_keypoints.json',
#  'video_000000002565_keypoints.json',
#  'video_000000002566_keypoints.json',
#  'video_000000002567_keypoints.json',
#  'video_000000002568_keypoints.json',
#  'video_000000002569_keypoints.json',
#  'video_000000002570_keypoints.json',
#  'video_000000002571_keypoints.json',
#  'video_000000002572_keypoints.json',
#  'video_000000002573_keypoints.json',
#  'video_000000002574_keypoints.json',
#  'video_000000002575_keypoints.json',
#  'video_000000002576_keypoints.json',
#  'video_000000002577_keypoints.json',
#  'video_000000002578_keypoints.json',
#  'video_000000002579_keypoints.json',
#  'video_000000002580_keypoints.json',
#  'video_000000002581_keypoints.json',
#  'video_000000002582_keypoints.json',
#  'video_000000002583_keypoints.json',
#  'video_000000002584_keypoints.json',
#  'video_000000002585_keypoints.json',
#  'video_000000002586_keypoints.json',
#  'video_000000002587_keypoints.json',
#  'video_000000002588_keypoints.json',
#  'video_000000002589_keypoints.json',
#  'video_000000002590_keypoints.json',
#  'video_000000002591_keypoints.json',
#  'video_000000002592_keypoints.json',
#  'video_000000002593_keypoints.json',
#  'video_000000002594_keypoints.json',
#  'video_000000002595_keypoints.json',
#  'video_000000002596_keypoints.json',
#  'video_000000002597_keypoints.json',
#  'video_000000002598_keypoints.json',
#  'video_000000002599_keypoints.json',
#  'video_000000002600_keypoints.json',
#  'video_000000002601_keypoints.json',
#  'video_000000002602_keypoints.json',
#  'video_000000002603_keypoints.json',
#  'video_000000002604_keypoints.json',
#  'video_000000002605_keypoints.json',
#  'video_000000002606_keypoints.json',
#  'video_000000002607_keypoints.json',
#  'video_000000002608_keypoints.json',
#  'video_000000002609_keypoints.json',
#  'video_000000002610_keypoints.json',
#  'video_000000002611_keypoints.json',
#  'video_000000002612_keypoints.json',
#  'video_000000002613_keypoints.json',
#  'video_000000002614_keypoints.json',
#  'video_000000002615_keypoints.json',
#  'video_000000002616_keypoints.json',
#  'video_000000002617_keypoints.json',
#  'video_000000002618_keypoints.json',
#  'video_000000002619_keypoints.json',
#  'video_000000002620_keypoints.json',
#  'video_000000002621_keypoints.json',
#  'video_000000002622_keypoints.json',
#  'video_000000002623_keypoints.json',
#  'video_000000002624_keypoints.json',
#  'video_000000002625_keypoints.json',
#  'video_000000002626_keypoints.json',
#  'video_000000002627_keypoints.json',
#  'video_000000002628_keypoints.json',
#  'video_000000002629_keypoints.json',
#  'video_000000002630_keypoints.json',
#  'video_000000002631_keypoints.json',
#  'video_000000002632_keypoints.json',
#  'video_000000002633_keypoints.json',
#  'video_000000002634_keypoints.json',
#  'video_000000002635_keypoints.json',
#  'video_000000002636_keypoints.json',
#  'video_000000002637_keypoints.json',
#  'video_000000002638_keypoints.json',
#  'video_000000002639_keypoints.json',
#  'video_000000002640_keypoints.json',
#  'video_000000002641_keypoints.json',
#  'video_000000002642_keypoints.json',
#  'video_000000002643_keypoints.json',
#  'video_000000002644_keypoints.json',
#  'video_000000002645_keypoints.json',
#  'video_000000002646_keypoints.json',
#  'video_000000002647_keypoints.json',
#  'video_000000002648_keypoints.json',
#  'video_000000002649_keypoints.json',
#  'video_000000002650_keypoints.json',
#  'video_000000002651_keypoints.json',
#  'video_000000002652_keypoints.json',
#  'video_000000002653_keypoints.json',
#  'video_000000002654_keypoints.json',
#  'video_000000002655_keypoints.json',
#  'video_000000002656_keypoints.json',
#  'video_000000002657_keypoints.json',
#  'video_000000002658_keypoints.json',
#  'video_000000002659_keypoints.json',
#  'video_000000002660_keypoints.json',
#  'video_000000002661_keypoints.json',
#  'video_000000002662_keypoints.json',
#  'video_000000002663_keypoints.json',
#  'video_000000002664_keypoints.json',
#  'video_000000002665_keypoints.json',
#  'video_000000002666_keypoints.json',
#  'video_000000002667_keypoints.json',
#  'video_000000002668_keypoints.json',
#  'video_000000002669_keypoints.json',
#  'video_000000002670_keypoints.json',
#  'video_000000002671_keypoints.json',
#  'video_000000002672_keypoints.json',
#  'video_000000002673_keypoints.json',
#  'video_000000002674_keypoints.json',
#  'video_000000002675_keypoints.json',
#  'video_000000002676_keypoints.json',
#  'video_000000002677_keypoints.json',
#  'video_000000002678_keypoints.json',
#  'video_000000002679_keypoints.json',
#  'video_000000002680_keypoints.json',
#  'video_000000002681_keypoints.json',
#  'video_000000002682_keypoints.json',
#  'video_000000002683_keypoints.json',
#  'video_000000002684_keypoints.json',
#  'video_000000002685_keypoints.json',
#  'video_000000002686_keypoints.json',
#  'video_000000002687_keypoints.json',
#  'video_000000002688_keypoints.json',
#  'video_000000002689_keypoints.json',
#  'video_000000002690_keypoints.json',
#  'video_000000002691_keypoints.json',
#  'video_000000002692_keypoints.json',
#  'video_000000002693_keypoints.json',
#  'video_000000002694_keypoints.json',
#  'video_000000002695_keypoints.json',
#  'video_000000002696_keypoints.json',
#  'video_000000002697_keypoints.json',
#  'video_000000002698_keypoints.json',
#  'video_000000002699_keypoints.json',
#  'video_000000002700_keypoints.json',
#  'video_000000002701_keypoints.json',
#  'video_000000002702_keypoints.json',
#  'video_000000002703_keypoints.json',
#  'video_000000002704_keypoints.json',
#  'video_000000002705_keypoints.json',
#  'video_000000002706_keypoints.json',
#  'video_000000002707_keypoints.json',
#  'video_000000002708_keypoints.json',
#  'video_000000002709_keypoints.json',
#  'video_000000002710_keypoints.json',
#  'video_000000002711_keypoints.json',
#  'video_000000002712_keypoints.json',
#  'video_000000002713_keypoints.json',
#  'video_000000002714_keypoints.json',
#  'video_000000002715_keypoints.json',
#  'video_000000002716_keypoints.json',
#  'video_000000002717_keypoints.json',
#  'video_000000002718_keypoints.json',
#  'video_000000002719_keypoints.json',
#  'video_000000002720_keypoints.json',
#  'video_000000002721_keypoints.json',
#  'video_000000002722_keypoints.json',
#  'video_000000002723_keypoints.json',
#  'video_000000002724_keypoints.json',
#  'video_000000002725_keypoints.json',
#  'video_000000002726_keypoints.json',
#  'video_000000002727_keypoints.json',
#  'video_000000002728_keypoints.json',
#  'video_000000002729_keypoints.json',
#  'video_000000002730_keypoints.json',
#  'video_000000002731_keypoints.json',
#  'video_000000002732_keypoints.json',
#  'video_000000002733_keypoints.json',
#  'video_000000002734_keypoints.json',
#  'video_000000002735_keypoints.json',
#  'video_000000002736_keypoints.json',
#  'video_000000002737_keypoints.json',
#  'video_000000002738_keypoints.json',
#  'video_000000002739_keypoints.json',
#  'video_000000002740_keypoints.json',
#  'video_000000002741_keypoints.json',
#  'video_000000002742_keypoints.json',
#  'video_000000002743_keypoints.json',
#  'video_000000002744_keypoints.json',
#  'video_000000002745_keypoints.json',
#  'video_000000002746_keypoints.json',
#  'video_000000002747_keypoints.json',
#  'video_000000002748_keypoints.json',
#  'video_000000002749_keypoints.json',
#  'video_000000002750_keypoints.json',
#  'video_000000002751_keypoints.json',
#  'video_000000002752_keypoints.json',
#  'video_000000002753_keypoints.json',
#  'video_000000002754_keypoints.json',
#  'video_000000002755_keypoints.json',
#  'video_000000002756_keypoints.json',
#  'video_000000002757_keypoints.json',
#  'video_000000002758_keypoints.json',
#  'video_000000002759_keypoints.json',
#  'video_000000002760_keypoints.json',
#  'video_000000002761_keypoints.json',
#  'video_000000002762_keypoints.json',
#  'video_000000002763_keypoints.json',
#  'video_000000002764_keypoints.json',
#  'video_000000002765_keypoints.json',
#  'video_000000002766_keypoints.json',
#  'video_000000002767_keypoints.json',
#  'video_000000002768_keypoints.json',
#  'video_000000002769_keypoints.json',
#  'video_000000002770_keypoints.json',
#  'video_000000002771_keypoints.json',
#  'video_000000002772_keypoints.json',
#  'video_000000002773_keypoints.json',
#  'video_000000002774_keypoints.json',
#  'video_000000002775_keypoints.json',
#  'video_000000002776_keypoints.json',
#  'video_000000002777_keypoints.json',
#  'video_000000002778_keypoints.json',
#  'video_000000002779_keypoints.json',
#  'video_000000002780_keypoints.json',
#  'video_000000002781_keypoints.json',
#  'video_000000002782_keypoints.json',
#  'video_000000002783_keypoints.json',
#  'video_000000002784_keypoints.json',
#  'video_000000002785_keypoints.json',
#  'video_000000002786_keypoints.json',
#  'video_000000002787_keypoints.json',
#  'video_000000002788_keypoints.json',
#  'video_000000002789_keypoints.json',
#  'video_000000002790_keypoints.json',
#  'video_000000002791_keypoints.json',
#  'video_000000002792_keypoints.json',
#  'video_000000002793_keypoints.json',
#  'video_000000002794_keypoints.json',
#  'video_000000002795_keypoints.json',
#  'video_000000002796_keypoints.json',
#  'video_000000002797_keypoints.json',
#  'video_000000002798_keypoints.json',
#  'video_000000002799_keypoints.json',
#  'video_000000002800_keypoints.json',
#  'video_000000002801_keypoints.json',
#  'video_000000002802_keypoints.json',
#  'video_000000002803_keypoints.json',
#  'video_000000002804_keypoints.json',
#  'video_000000002805_keypoints.json',
#  'video_000000002806_keypoints.json',
#  'video_000000002807_keypoints.json',
#  'video_000000002808_keypoints.json',
#  'video_000000002809_keypoints.json',
#  'video_000000002810_keypoints.json',
#  'video_000000002811_keypoints.json',
#  'video_000000002812_keypoints.json',
#  'video_000000002813_keypoints.json',
#  'video_000000002814_keypoints.json',
#  'video_000000002815_keypoints.json',
#  'video_000000002816_keypoints.json',
#  'video_000000002817_keypoints.json',
#  'video_000000002818_keypoints.json',
#  'video_000000002819_keypoints.json',
#  'video_000000002820_keypoints.json',
#  'video_000000002821_keypoints.json',
#  'video_000000002822_keypoints.json',
#  'video_000000002823_keypoints.json',
#  'video_000000002824_keypoints.json',
#  'video_000000002825_keypoints.json',
#  'video_000000002826_keypoints.json',
#  'video_000000002827_keypoints.json',
#  'video_000000002828_keypoints.json',
#  'video_000000002829_keypoints.json',
#  'video_000000002830_keypoints.json',
#  'video_000000002831_keypoints.json',
#  'video_000000002832_keypoints.json',
#  'video_000000002833_keypoints.json',
#  'video_000000002834_keypoints.json',
#  'video_000000002835_keypoints.json',
#  'video_000000002836_keypoints.json',
#  'video_000000002837_keypoints.json',
#  'video_000000002838_keypoints.json',
#  'video_000000002839_keypoints.json',
#  'video_000000002840_keypoints.json',
#  'video_000000002841_keypoints.json',
#  'video_000000002842_keypoints.json',
#  'video_000000002843_keypoints.json',
#  'video_000000002844_keypoints.json',
#  'video_000000002845_keypoints.json',
#  'video_000000002846_keypoints.json',
#  'video_000000002847_keypoints.json',
#  'video_000000002848_keypoints.json',
#  'video_000000002849_keypoints.json',
#  'video_000000002850_keypoints.json',
#  'video_000000002851_keypoints.json',
#  'video_000000002852_keypoints.json',
#  'video_000000002853_keypoints.json',
#  'video_000000002854_keypoints.json',
#  'video_000000002855_keypoints.json',
#  'video_000000002856_keypoints.json',
#  'video_000000002857_keypoints.json',
#  'video_000000002858_keypoints.json',
#  'video_000000002859_keypoints.json',
#  'video_000000002860_keypoints.json',
#  'video_000000002861_keypoints.json',
#  'video_000000002862_keypoints.json',
#  'video_000000002863_keypoints.json',
#  'video_000000002864_keypoints.json',
#  'video_000000002865_keypoints.json',
#  'video_000000002866_keypoints.json',
#  'video_000000002867_keypoints.json',
#  'video_000000002868_keypoints.json',
#  'video_000000002869_keypoints.json',
#  'video_000000002870_keypoints.json',
#  'video_000000002871_keypoints.json',
#  'video_000000002872_keypoints.json',
#  'video_000000002873_keypoints.json',
#  'video_000000002874_keypoints.json',
#  'video_000000002875_keypoints.json',
#  'video_000000002876_keypoints.json',
#  'video_000000002877_keypoints.json',
#  'video_000000002878_keypoints.json',
#  'video_000000002879_keypoints.json',
#  'video_000000002880_keypoints.json',
#  'video_000000002881_keypoints.json',
#  'video_000000002882_keypoints.json',
#  'video_000000002883_keypoints.json',
#  'video_000000002884_keypoints.json',
#  'video_000000002885_keypoints.json',
#  'video_000000002886_keypoints.json',
#  'video_000000002887_keypoints.json',
#  'video_000000002888_keypoints.json',
#  'video_000000002889_keypoints.json',
#  'video_000000002890_keypoints.json',
#  'video_000000002891_keypoints.json',
#  'video_000000002892_keypoints.json',
#  'video_000000002893_keypoints.json',
#  'video_000000002894_keypoints.json',
#  'video_000000002895_keypoints.json',
#  'video_000000002896_keypoints.json',
#  'video_000000002897_keypoints.json',
#  'video_000000002898_keypoints.json',
#  'video_000000002899_keypoints.json',
#  'video_000000002900_keypoints.json',
#  'video_000000002901_keypoints.json',
#  'video_000000002902_keypoints.json',
#  'video_000000002903_keypoints.json',
#  'video_000000002904_keypoints.json',
#  'video_000000002905_keypoints.json',
#  'video_000000002906_keypoints.json',
#  'video_000000002907_keypoints.json',
#  'video_000000002908_keypoints.json',
#  'video_000000002909_keypoints.json',
#  'video_000000002910_keypoints.json',
#  'video_000000002911_keypoints.json',
#  'video_000000002912_keypoints.json',
#  'video_000000002913_keypoints.json',
#  'video_000000002914_keypoints.json',
#  'video_000000002915_keypoints.json',
#  'video_000000002916_keypoints.json',
#  'video_000000002917_keypoints.json',
#  'video_000000002918_keypoints.json',
#  'video_000000002919_keypoints.json',
#  'video_000000002920_keypoints.json',
#  'video_000000002921_keypoints.json',
#  'video_000000002922_keypoints.json',
#  'video_000000002923_keypoints.json',
#  'video_000000002924_keypoints.json',
#  'video_000000002925_keypoints.json',
#  'video_000000002926_keypoints.json',
#  'video_000000002927_keypoints.json',
#  'video_000000002928_keypoints.json',
#  'video_000000002929_keypoints.json',
#  'video_000000002930_keypoints.json',
#  'video_000000002931_keypoints.json',
#  'video_000000002932_keypoints.json',
#  'video_000000002933_keypoints.json',
#  'video_000000002934_keypoints.json',
#  'video_000000002935_keypoints.json',
#  'video_000000002936_keypoints.json',
#  'video_000000002937_keypoints.json',
#  'video_000000002938_keypoints.json',
#  'video_000000002939_keypoints.json',
#  'video_000000002940_keypoints.json',
#  'video_000000002941_keypoints.json',
#  'video_000000002942_keypoints.json',
#  'video_000000002943_keypoints.json',
#  'video_000000002944_keypoints.json',
#  'video_000000002945_keypoints.json',
#  'video_000000002946_keypoints.json',
#  'video_000000002947_keypoints.json',
#  'video_000000002948_keypoints.json',
#  'video_000000002949_keypoints.json',
#  'video_000000002950_keypoints.json',
#  'video_000000002951_keypoints.json',
#  'video_000000002952_keypoints.json',
#  'video_000000002953_keypoints.json',
#  'video_000000002954_keypoints.json',
#  'video_000000002955_keypoints.json',
#  'video_000000002956_keypoints.json',
#  'video_000000002957_keypoints.json',
#  'video_000000002958_keypoints.json',
#  'video_000000002959_keypoints.json',
#  'video_000000002960_keypoints.json',
#  'video_000000002961_keypoints.json',
#  'video_000000002962_keypoints.json',
#  'video_000000002963_keypoints.json',
#  'video_000000002964_keypoints.json',
#  'video_000000002965_keypoints.json',
#  'video_000000002966_keypoints.json',
#  'video_000000002967_keypoints.json',
#  'video_000000002968_keypoints.json',
#  'video_000000002969_keypoints.json',
#  'video_000000002970_keypoints.json',
#  'video_000000002971_keypoints.json',
#  'video_000000002972_keypoints.json',
#  'video_000000002973_keypoints.json',
#  'video_000000002974_keypoints.json',
#  'video_000000002975_keypoints.json',
#  'video_000000002976_keypoints.json',
#  'video_000000002977_keypoints.json',
#  'video_000000002978_keypoints.json',
#  'video_000000002979_keypoints.json',
#  'video_000000002980_keypoints.json',
#  'video_000000002981_keypoints.json',
#  'video_000000002982_keypoints.json',
#  'video_000000002983_keypoints.json',
#  'video_000000002984_keypoints.json',
#  'video_000000002985_keypoints.json',
#  'video_000000002986_keypoints.json',
#  'video_000000002987_keypoints.json',
#  'video_000000002988_keypoints.json',
#  'video_000000002989_keypoints.json',
#  'video_000000002990_keypoints.json',
#  'video_000000002991_keypoints.json',
#  'video_000000002992_keypoints.json',
#  'video_000000002993_keypoints.json',
#  'video_000000002994_keypoints.json',
#  'video_000000002995_keypoints.json',
#  'video_000000002996_keypoints.json',
#  'video_000000002997_keypoints.json',
#  'video_000000002998_keypoints.json',
#  'video_000000002999_keypoints.json',
#  'video_000000003000_keypoints.json',
#  'video_000000003001_keypoints.json',
#  'video_000000003002_keypoints.json',
#  'video_000000003003_keypoints.json',
#  'video_000000003004_keypoints.json',
#  'video_000000003005_keypoints.json',
#  'video_000000003006_keypoints.json',
#  'video_000000003007_keypoints.json',
#  'video_000000003008_keypoints.json',
#  'video_000000003009_keypoints.json',
#  'video_000000003010_keypoints.json',
#  'video_000000003011_keypoints.json',
#  'video_000000003012_keypoints.json',
#  'video_000000003013_keypoints.json',
#  'video_000000003014_keypoints.json',
#  'video_000000003015_keypoints.json',
#  'video_000000003016_keypoints.json',
#  'video_000000003017_keypoints.json',
#  'video_000000003018_keypoints.json',
#  'video_000000003019_keypoints.json',
#  'video_000000003020_keypoints.json',
#  'video_000000003021_keypoints.json',
#  'video_000000003022_keypoints.json',
#  'video_000000003023_keypoints.json',
#  'video_000000003024_keypoints.json',
#  'video_000000003025_keypoints.json',
#  'video_000000003026_keypoints.json',
#  'video_000000003027_keypoints.json',
#  'video_000000003028_keypoints.json',
#  'video_000000003029_keypoints.json',
#  'video_000000003030_keypoints.json',
#  'video_000000003031_keypoints.json',
#  'video_000000003032_keypoints.json',
#  'video_000000003033_keypoints.json',
#  'video_000000003034_keypoints.json',
#  'video_000000003035_keypoints.json',
#  'video_000000003036_keypoints.json',
#  'video_000000003037_keypoints.json',
#  'video_000000003038_keypoints.json',
#  'video_000000003039_keypoints.json',
#  'video_000000003040_keypoints.json',
#  'video_000000003041_keypoints.json',
#  'video_000000003042_keypoints.json',
#  'video_000000003043_keypoints.json',
#  'video_000000003044_keypoints.json',
#  'video_000000003045_keypoints.json',
#  'video_000000003046_keypoints.json',
#  'video_000000003047_keypoints.json',
#  'video_000000003048_keypoints.json',
#  'video_000000003049_keypoints.json',
#  'video_000000003050_keypoints.json',
#  'video_000000003051_keypoints.json',
#  'video_000000003052_keypoints.json',
#  'video_000000003053_keypoints.json',
#  'video_000000003054_keypoints.json',
#  'video_000000003055_keypoints.json',
#  'video_000000003056_keypoints.json',
#  'video_000000003057_keypoints.json',
#  'video_000000003058_keypoints.json',
#  'video_000000003059_keypoints.json',
#  'video_000000003060_keypoints.json',
#  'video_000000003061_keypoints.json',
#  'video_000000003062_keypoints.json',
#  'video_000000003063_keypoints.json',
#  'video_000000003064_keypoints.json',
#  'video_000000003065_keypoints.json',
#  'video_000000003066_keypoints.json',
#  'video_000000003067_keypoints.json',
#  'video_000000003068_keypoints.json',
#  'video_000000003069_keypoints.json',
#  'video_000000003070_keypoints.json',
#  'video_000000003071_keypoints.json',
#  'video_000000003072_keypoints.json',
#  'video_000000003073_keypoints.json',
#  'video_000000003074_keypoints.json',
#  'video_000000003075_keypoints.json',
#  'video_000000003076_keypoints.json',
#  'video_000000003077_keypoints.json',
#  'video_000000003078_keypoints.json',
#  'video_000000003079_keypoints.json',
#  'video_000000003080_keypoints.json',
#  'video_000000003081_keypoints.json',
#  'video_000000003082_keypoints.json',
#  'video_000000003083_keypoints.json',
#  'video_000000003084_keypoints.json',
#  'video_000000003085_keypoints.json',
#  'video_000000003086_keypoints.json',
#  'video_000000003087_keypoints.json',
#  'video_000000003088_keypoints.json',
#  'video_000000003089_keypoints.json',
#  'video_000000003090_keypoints.json',
#  'video_000000003091_keypoints.json',
#  'video_000000003092_keypoints.json',
#  'video_000000003093_keypoints.json',
#  'video_000000003094_keypoints.json',
#  'video_000000003095_keypoints.json',
#  'video_000000003096_keypoints.json',
#  'video_000000003097_keypoints.json',
#  'video_000000003098_keypoints.json',
#  'video_000000003099_keypoints.json',
#  'video_000000003100_keypoints.json',
#  'video_000000003101_keypoints.json',
#  'video_000000003102_keypoints.json',
#  'video_000000003103_keypoints.json',
#  'video_000000003104_keypoints.json',
#  'video_000000003105_keypoints.json',
#  'video_000000003106_keypoints.json',
#  'video_000000003107_keypoints.json',
#  'video_000000003108_keypoints.json',
#  'video_000000003109_keypoints.json',
#  'video_000000003110_keypoints.json',
#  'video_000000003111_keypoints.json',
#  'video_000000003112_keypoints.json',
#  'video_000000003113_keypoints.json',
#  'video_000000003114_keypoints.json',
#  'video_000000003115_keypoints.json',
#  'video_000000003116_keypoints.json',
#  'video_000000003117_keypoints.json',
#  'video_000000003118_keypoints.json',
#  'video_000000003119_keypoints.json',
#  'video_000000003120_keypoints.json',
#  'video_000000003121_keypoints.json',
#  'video_000000003122_keypoints.json',
#  'video_000000003123_keypoints.json',
#  'video_000000003124_keypoints.json',
#  'video_000000003125_keypoints.json',
#  'video_000000003126_keypoints.json',
#  'video_000000003127_keypoints.json',
#  'video_000000003128_keypoints.json',
#  'video_000000003129_keypoints.json',
#  'video_000000003130_keypoints.json',
#  'video_000000003131_keypoints.json',
#  'video_000000003132_keypoints.json',
#  'video_000000003133_keypoints.json',
#  'video_000000003134_keypoints.json',
#  'video_000000003135_keypoints.json',
#  'video_000000003136_keypoints.json',
#  'video_000000003137_keypoints.json',
#  'video_000000003138_keypoints.json',
#  'video_000000003139_keypoints.json',
#  'video_000000003140_keypoints.json',
#  'video_000000003141_keypoints.json',
#  'video_000000003142_keypoints.json',
#  'video_000000003143_keypoints.json',
#  'video_000000003144_keypoints.json',
#  'video_000000003145_keypoints.json',
#  'video_000000003146_keypoints.json',
#  'video_000000003147_keypoints.json',
#  'video_000000003148_keypoints.json',
#  'video_000000003149_keypoints.json',
#  'video_000000003150_keypoints.json',
#  'video_000000003151_keypoints.json',
#  'video_000000003152_keypoints.json',
#  'video_000000003153_keypoints.json',
#  'video_000000003154_keypoints.json',
#  'video_000000003155_keypoints.json',
#  'video_000000003156_keypoints.json',
#  'video_000000003157_keypoints.json',
#  'video_000000003158_keypoints.json',
#  'video_000000003159_keypoints.json',
#  'video_000000003160_keypoints.json',
#  'video_000000003161_keypoints.json',
#  'video_000000003162_keypoints.json',
#  'video_000000003163_keypoints.json',
#  'video_000000003164_keypoints.json',
#  'video_000000003165_keypoints.json',
#  'video_000000003166_keypoints.json',
#  'video_000000003167_keypoints.json',
#  'video_000000003168_keypoints.json',
#  'video_000000003169_keypoints.json',
#  'video_000000003170_keypoints.json',
#  'video_000000003171_keypoints.json',
#  'video_000000003172_keypoints.json',
#  'video_000000003173_keypoints.json',
#  'video_000000003174_keypoints.json',
#  'video_000000003175_keypoints.json',
#  'video_000000003176_keypoints.json',
#  'video_000000003177_keypoints.json',
#  'video_000000003178_keypoints.json',
#  'video_000000003179_keypoints.json',
#  'video_000000003180_keypoints.json',
#  'video_000000003181_keypoints.json',
#  'video_000000003182_keypoints.json',
#  'video_000000003183_keypoints.json',
#  'video_000000003184_keypoints.json',
#  'video_000000003185_keypoints.json',
#  'video_000000003186_keypoints.json',
#  'video_000000003187_keypoints.json',
#  'video_000000003188_keypoints.json',
#  'video_000000003189_keypoints.json',
#  'video_000000003190_keypoints.json',
#  'video_000000003191_keypoints.json',
#  'video_000000003192_keypoints.json',
#  'video_000000003193_keypoints.json',
#  'video_000000003194_keypoints.json',
#  'video_000000003195_keypoints.json',
#  'video_000000003196_keypoints.json',
#  'video_000000003197_keypoints.json',
#  'video_000000003198_keypoints.json',
#  'video_000000003199_keypoints.json',
#  'video_000000003200_keypoints.json',
#  'video_000000003201_keypoints.json',
#  'video_000000003202_keypoints.json',
#  'video_000000003203_keypoints.json',
#  'video_000000003204_keypoints.json',
#  'video_000000003205_keypoints.json',
#  'video_000000003206_keypoints.json',
#  'video_000000003207_keypoints.json',
#  'video_000000003208_keypoints.json',
#  'video_000000003209_keypoints.json',
#  'video_000000003210_keypoints.json',
#  'video_000000003211_keypoints.json',
#  'video_000000003212_keypoints.json',
#  'video_000000003213_keypoints.json',
#  'video_000000003214_keypoints.json',
#  'video_000000003215_keypoints.json',
#  'video_000000003216_keypoints.json',
#  'video_000000003217_keypoints.json',
#  'video_000000003218_keypoints.json',
#  'video_000000003219_keypoints.json',
#  'video_000000003220_keypoints.json',
#  'video_000000003221_keypoints.json',
#  'video_000000003222_keypoints.json',
#  'video_000000003223_keypoints.json',
#  'video_000000003224_keypoints.json',
#  'video_000000003225_keypoints.json',
#  'video_000000003226_keypoints.json',
#  'video_000000003227_keypoints.json',
#  'video_000000003228_keypoints.json',
#  'video_000000003229_keypoints.json',
#  'video_000000003230_keypoints.json',
#  'video_000000003231_keypoints.json',
#  'video_000000003232_keypoints.json',
#  'video_000000003233_keypoints.json',
#  'video_000000003234_keypoints.json',
#  'video_000000003235_keypoints.json',
#  'video_000000003236_keypoints.json',
#  'video_000000003237_keypoints.json',
#  'video_000000003238_keypoints.json',
#  'video_000000003239_keypoints.json',
#  'video_000000003240_keypoints.json',
#  'video_000000003241_keypoints.json',
#  'video_000000003242_keypoints.json',
#  'video_000000003243_keypoints.json',
#  'video_000000003244_keypoints.json',
#  'video_000000003245_keypoints.json',
#  'video_000000003246_keypoints.json',
#  'video_000000003247_keypoints.json',
#  'video_000000003248_keypoints.json',
#  'video_000000003249_keypoints.json',
#  'video_000000003250_keypoints.json',
#  'video_000000003251_keypoints.json',
#  'video_000000003252_keypoints.json',
#  'video_000000003253_keypoints.json',
#  'video_000000003254_keypoints.json',
#  'video_000000003255_keypoints.json',
#  'video_000000003256_keypoints.json',
#  'video_000000003257_keypoints.json',
#  'video_000000003258_keypoints.json',
#  'video_000000003259_keypoints.json',
#  'video_000000003260_keypoints.json',
#  'video_000000003261_keypoints.json',
#  'video_000000003262_keypoints.json',
#  'video_000000003263_keypoints.json',
#  'video_000000003264_keypoints.json',
#  'video_000000003265_keypoints.json',
#  'video_000000003266_keypoints.json',
#  'video_000000003267_keypoints.json',
#  'video_000000003268_keypoints.json',
#  'video_000000003269_keypoints.json',
#  'video_000000003270_keypoints.json',
#  'video_000000003271_keypoints.json',
#  'video_000000003272_keypoints.json',
#  'video_000000003273_keypoints.json',
#  'video_000000003274_keypoints.json',
#  'video_000000003275_keypoints.json',
#  'video_000000003276_keypoints.json',
#  'video_000000003277_keypoints.json',
#  'video_000000003278_keypoints.json',
#  'video_000000003279_keypoints.json',
#  'video_000000003280_keypoints.json',
#  'video_000000003281_keypoints.json',
#  'video_000000003282_keypoints.json',
#  'video_000000003283_keypoints.json',
#  'video_000000003284_keypoints.json',
#  'video_000000003285_keypoints.json',
#  'video_000000003286_keypoints.json',
#  'video_000000003287_keypoints.json',
#  'video_000000003288_keypoints.json',
#  'video_000000003289_keypoints.json',
#  'video_000000003290_keypoints.json',
#  'video_000000003291_keypoints.json',
#  'video_000000003292_keypoints.json',
#  'video_000000003293_keypoints.json',
#  'video_000000003294_keypoints.json',
#  'video_000000003295_keypoints.json',
#  'video_000000003296_keypoints.json',
#  'video_000000003297_keypoints.json',
#  'video_000000003298_keypoints.json',
#  'video_000000003299_keypoints.json',
#  'video_000000003300_keypoints.json',
#  'video_000000003301_keypoints.json',
#  'video_000000003302_keypoints.json',
#  'video_000000003303_keypoints.json',
#  'video_000000003304_keypoints.json',
#  'video_000000003305_keypoints.json',
#  'video_000000003306_keypoints.json',
#  'video_000000003307_keypoints.json',
#  'video_000000003308_keypoints.json',
#  'video_000000003309_keypoints.json',
#  'video_000000003310_keypoints.json',
#  'video_000000003311_keypoints.json',
#  'video_000000003312_keypoints.json',
#  'video_000000003313_keypoints.json',
#  'video_000000003314_keypoints.json',
#  'video_000000003315_keypoints.json',
#  'video_000000003316_keypoints.json',
#  'video_000000003317_keypoints.json',
#  'video_000000003318_keypoints.json',
#  'video_000000003319_keypoints.json',
#  'video_000000003320_keypoints.json',
#  'video_000000003321_keypoints.json',
#  'video_000000003322_keypoints.json',
#  'video_000000003323_keypoints.json',
#  'video_000000003324_keypoints.json',
#  'video_000000003325_keypoints.json',
#  'video_000000003326_keypoints.json',
#  'video_000000003327_keypoints.json',
#  'video_000000003328_keypoints.json',
#  'video_000000003329_keypoints.json',
#  'video_000000003330_keypoints.json',
#  'video_000000003331_keypoints.json',
#  'video_000000003332_keypoints.json',
#  'video_000000003333_keypoints.json',
#  'video_000000003334_keypoints.json',
#  'video_000000003335_keypoints.json',
#  'video_000000003336_keypoints.json',
#  'video_000000003337_keypoints.json',
#  'video_000000003338_keypoints.json',
#  'video_000000003339_keypoints.json',
#  'video_000000003340_keypoints.json',
#  'video_000000003341_keypoints.json',
#  'video_000000003342_keypoints.json',
#  'video_000000003343_keypoints.json',
#  'video_000000003344_keypoints.json',
#  'video_000000003345_keypoints.json',
#  'video_000000003346_keypoints.json',
#  'video_000000003347_keypoints.json',
#  'video_000000003348_keypoints.json',
#  'video_000000003349_keypoints.json',
#  'video_000000003350_keypoints.json',
#  'video_000000003351_keypoints.json',
#  'video_000000003352_keypoints.json',
#  'video_000000003353_keypoints.json',
#  'video_000000003354_keypoints.json',
#  'video_000000003355_keypoints.json',
#  'video_000000003356_keypoints.json',
#  'video_000000003357_keypoints.json',
#  'video_000000003358_keypoints.json',
#  'video_000000003359_keypoints.json',
#  'video_000000003360_keypoints.json',
#  'video_000000003361_keypoints.json',
#  'video_000000003362_keypoints.json',
#  'video_000000003363_keypoints.json',
#  'video_000000003364_keypoints.json',
#  'video_000000003365_keypoints.json',
#  'video_000000003366_keypoints.json',
#  'video_000000003367_keypoints.json',
#  'video_000000003368_keypoints.json',
#  'video_000000003369_keypoints.json',
#  'video_000000003370_keypoints.json',
#  'video_000000003371_keypoints.json',
#  'video_000000003372_keypoints.json',
#  'video_000000003373_keypoints.json',
#  'video_000000003374_keypoints.json',
#  'video_000000003375_keypoints.json',
#  'video_000000003376_keypoints.json',
#  'video_000000003377_keypoints.json',
#  'video_000000003378_keypoints.json',
#  'video_000000003379_keypoints.json',
#  'video_000000003380_keypoints.json',
#  'video_000000003381_keypoints.json',
#  'video_000000003382_keypoints.json',
#  'video_000000003383_keypoints.json',
#  'video_000000003384_keypoints.json',
#  'video_000000003385_keypoints.json',
#  'video_000000003386_keypoints.json']

# %%
print(len(all_json_files))
# Out:
# 929

# %%
filename = os.path.join(JSON_DATA_PATH, all_json_files[1])

# %%
print(filename)
# Out:
# /Users/sreeharirammohan/Desktop/SCP_FOLDER/video_2/json/video_000000002459_keypoints.json

# %%
'''
This method finds the angle between the 8-9 and 9-10 segments. 
'''
def determine_angle_for_json_file(json_file_data, person_number, segment1, segment2):
    
    first_coordinate = int(segment1.split('-')[0])
    
    second_coordinate = int(segment1.split('-')[1])
    
    redundant_second_coordinate = int(segment2.split('-')[0])
    
    third_coordinate = int(segment2.split('-')[1])
    
    if not redundant_second_coordinate == second_coordinate:
        print("ERROR: Two points you find the angle between must be adjacent (share a common vertex)")
        return None
    
    #print(first_coordinate, second_coordinate, third_coordinate)
    
    #No people detected in the scene
    if (len(json_file_data["people"]) == 0):
        return
    
    # 8th segment x, y
    x_8 = json_file_data["people"][person_number]["pose_keypoints_2d"][3*first_coordinate]
    y_8 = json_file_data["people"][person_number]["pose_keypoints_2d"][3*first_coordinate + 1]

    # 9th segment x, y
    x_9 = json_file_data["people"][person_number]["pose_keypoints_2d"][3*second_coordinate]
    y_9 = json_file_data["people"][person_number]["pose_keypoints_2d"][3*second_coordinate + 1]

    #10th
    x_10 = json_file_data["people"][person_number]["pose_keypoints_2d"][3*third_coordinate]
    y_10 = json_file_data["people"][person_number]["pose_keypoints_2d"][3*third_coordinate + 1]
    
    
    if (x_9 == x_8 or x_10 == x_9):
        return 180 #standing straight up
    
    slope_8_9 = (y_9 - y_8)/(x_9 - x_8)
    slope_9_10 = (y_10 - y_9)/(x_10 - x_9)
    
    temp_calc = (slope_9_10 - slope_8_9)/(1 + slope_8_9*slope_9_10)
    
    angle_rad = np.arctan(temp_calc)
    
    angle = angle_rad * (180/np.pi)
    
    
    if(angle < 0):
        angle = -angle
    
    
        
    return angle

# %%
frame_number = 0
angles = []

for name in all_json_files:
    
    filename = os.path.join(JSON_DATA_PATH, name)
    
    with open(filename, 'r') as j:
        json_file_data = json.load(j)
        angle = determine_angle_for_json_file(json_file_data=json_file_data, person_number=0, segment1="8-9", segment2='9-10')
        angles.append(angle)
        frame_number += 1

# %%
len(angles)
# Out:
# 929

# %%
frame_number
# Out:
# 929

# %%
frame_x = list(range(0, frame_number))

# %%
plt.figure(figsize=(20,5))

plt.plot(frame_x, angles)
# count the number of times the person squatted based on the number of times the angle is 90 degrees

# %%
from scipy.ndimage.filters import gaussian_filter1d
from scipy.signal import find_peaks

y_filtered = gaussian_filter1d(angles, 6)
plt.figure(figsize=(20,5))

plt.plot(frame_x, y_filtered)

find_peaks_cwt(y_filtered, )
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-45-7df972ad8f41> in <module>()
#       1 from scipy.ndimage.filters import gaussian_filter1d
# ----> 2 from scipy.signal import find_peaks
#       3
#       4 y_filtered = gaussian_filter1d(angles, 6)
#       5 plt.figure(figsize=(20,5))
#
# ImportError: cannot import name 'find_peaks'

# %%
print(json.dumps(json_file_data, indent=1, sort_keys=True))
# Out:
# {
#  "people": [
#   {
#    "face_keypoints_2d": [],
#    "face_keypoints_3d": [],
#    "hand_left_keypoints_2d": [],
#    "hand_left_keypoints_3d": [],
#    "hand_right_keypoints_2d": [],
#    "hand_right_keypoints_3d": [],
#    "pose_keypoints_2d": [
#     472.949,
#     223.671,
#     0.851208,
#     433.827,
#     234.068,
#     0.756772,
#     442.903,
#     235.46,
#     0.779556,
#     454.656,
#     278.545,
#     0.73852,
#     440.349,
#     294.166,
#     0.196527,
#     427.277,
#     226.316,
#     0.606573,
#     0,
#     0,
#     0,
#     0,
#     0,
#     0,
#     375.074,
#     301.987,
#     0.519537,
#     379.012,
#     304.581,
#     0.568668,
#     457.319,
#     318.927,
#     0.739473,
#     458.611,
#     401.222,
#     0.582541,
#     369.851,
#     299.403,
#     0.393886,
#     459.899,
#     317.665,
#     0.548177,
#     449.488,
#     401.191,
#     0.565165,
#     471.662,
#     214.557,
#     0.844839,
#     0,
#     0,
#     0,
#     454.701,
#     209.331,
#     0.821199,
#     0,
#     0,
#     0,
#     476.872,
#     411.653,
#     0.163969,
#     0,
#     0,
#     0,
#     441.602,
#     410.317,
#     0.535615,
#     487.313,
#     412.935,
#     0.665607,
#     478.197,
#     416.855,
#     0.599619,
#     450.789,
#     411.652,
#     0.476894
#    ],
#    "pose_keypoints_3d": []
#   }
#  ],
#  "version": 1.2
# }

# %%
json_file_data["people"][0]["pose_keypoints_2d"][8]
# Out:
# 0.905666

# %%
determine_angle_for_json_file(json_file_data=json_file_data, person_number=0, segment1="8-9", segment2='9-10')
# Out:
# 83.84331528274771
